# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv(r"C:\Users\CTTC1\Downloads\adult.data",header=None,delimiter=' *, *',engine='python')
data     
#'header' makes the first row to come to the dataset adn not get transfered to the column heading
#'delimiter' removes the blank spaces from front and back of each input data
#'engine' defines the kernel engine as 'python'
# Out:
#        0                 1       2           3   4                   5   \
# 0      39         State-gov   77516   Bachelors  13       Never-married
# 1      50  Self-emp-not-inc   83311   Bachelors  13  Married-civ-spouse
# 2      38           Private  215646     HS-grad   9            Divorced
# 3      53           Private  234721        11th   7  Married-civ-spouse
# 4      28           Private  338409   Bachelors  13  Married-civ-spouse
# ...    ..               ...     ...         ...  ..                 ...
# 32556  27           Private  257302  Assoc-acdm  12  Married-civ-spouse
# 32557  40           Private  154374     HS-grad   9  Married-civ-spouse
# 32558  58           Private  151910     HS-grad   9             Widowed
# 32559  22           Private  201490     HS-grad   9       Never-married
# 32560  52      Self-emp-inc  287927     HS-grad   9  Married-civ-spouse
#
#                       6              7      8       9      10  11  12  \
# ...

# %%
data.columns = ['age','work_class','fnlwgt','education','education_num','maritial_status','occupation','relationship','race','sex','capital_gain','capital_loss','hours_per-week','native_country','Salary']
data
#renaming the header as not as indexes, but as attributes
# Out:
#        age        work_class  fnlwgt   education  education_num  \
# 0       39         State-gov   77516   Bachelors             13
# 1       50  Self-emp-not-inc   83311   Bachelors             13
# 2       38           Private  215646     HS-grad              9
# 3       53           Private  234721        11th              7
# 4       28           Private  338409   Bachelors             13
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm             12
# 32557   40           Private  154374     HS-grad              9
# 32558   58           Private  151910     HS-grad              9
# 32559   22           Private  201490     HS-grad              9
# 32560   52      Self-emp-inc  287927     HS-grad              9
#
#           maritial_status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# ...

# %%
for i in data.columns:
    print(i,':',sum(data[i]=='?'))
#checks the number of '?' in each column using the 'sum' command
# Out:
# age : 0
# work_class : 1836
# fnlwgt : 0
# education : 0
# education_num : 0
# maritial_status : 0
# occupation : 1843
# relationship : 0
# race : 0
# sex : 0
# capital_gain : 0
# capital_loss : 0
# hours_per-week : 0
# native_country : 583
# Salary : 0

# %%
d1 = data.describe(include='all')
d1
#stores the description in terms of both numeric and string valued columns in another data set variable
# Out:
#                  age work_class        fnlwgt education  education_num  \
# count   32561.000000      32561  3.256100e+04     32561   32561.000000
# unique           NaN          9           NaN        16            NaN
# top              NaN    Private           NaN   HS-grad            NaN
# freq             NaN      22696           NaN     10501            NaN
# mean       38.581647        NaN  1.897784e+05       NaN      10.080679
# std        13.640433        NaN  1.055500e+05       NaN       2.572720
# min        17.000000        NaN  1.228500e+04       NaN       1.000000
# 25%        28.000000        NaN  1.178270e+05       NaN       9.000000
# 50%        37.000000        NaN  1.783560e+05       NaN      10.000000
# 75%        48.000000        NaN  2.370510e+05       NaN      12.000000
# max        90.000000        NaN  1.484705e+06       NaN      16.000000
#
#            maritial_status      occupation relationship   race    sex  \
# ...

# %%
for i in ['work_class','occupation','native_country']:
    data[i].replace('?',d1[i][2],inplace=True)
#Replaces the missing datas having '?' with the top repeated values in that columns

# %%
for i in data.columns:
    print(i,':',sum(data[i]=='?'))
#checks the number of '?' in each column using the 'sum' command
# Out:
# age : 0
# work_class : 0
# fnlwgt : 0
# education : 0
# education_num : 0
# maritial_status : 0
# occupation : 0
# relationship : 0
# race : 0
# sex : 0
# capital_gain : 0
# capital_loss : 0
# hours_per-week : 0
# native_country : 0
# Salary : 0

# %% [markdown]
# # Histogram age<->salary

# %%
sns.displot(data.age[data.Salary=='>50K'])     #shows the histogram 
sns.displot(data.age[data.Salary=='<=50K'])    #shows the histogram
plt.legend(['More salary','Less salary'])
plt.show()

# %% [markdown]
# # KDE age<->salary

# %%
sns.kdeplot(data.age[data.Salary=='>50K'])     #shows the kernel density estimation 
sns.kdeplot(data.age[data.Salary=='<=50K'])    #shows the kernel density estimation
plt.legend(['More salary','Less salary'])
plt.show()

# %% [markdown]
# # Count plot work_class<->salary

# %%
plt.figure(figsize=(15,10))
sns.countplot(x=data.work_class,hue=data.Salary)
plt.show()

# %% [markdown]
# # Count plot education<->salary

# %%
plt.figure(figsize=(25,30))
sns.countplot(x=data.education,hue=data.Salary)
plt.show()

# %% [markdown]
# # Count plot education_num<->salary

# %%
plt.figure(figsize=(15,10))
sns.countplot(x=data.education_num,hue=data.Salary)
plt.show()

# %% [markdown]
# # Count plot martial_status<->salary

# %%
plt.figure(figsize=(15,10))
sns.countplot(x=data.maritial_status,hue=data.Salary)
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.countplot(x=data.maritial_status,hue=data.Salary)
plt.show()

# %% [markdown]
# # Count plot Occupation<->salary

# %%
plt.figure(figsize=(25,15))
sns.countplot(x=data.occupation,hue=data.Salary)
plt.show()
